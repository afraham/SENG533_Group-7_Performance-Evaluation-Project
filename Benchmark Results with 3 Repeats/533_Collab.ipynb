# %% [markdown]
# # SVHN Benchmark: MLP, RNN, CNN on Colab & Kaggle

# %% [markdown]
# ## How to use
# 1. **Select accelerator** in your notebook settings (GPU for GPU runs). The notebook can still force **CPU** even on a GPU runtime.
# 2. Edit the **parameters** in the next cell. For the full factorial at one platform, use `fractions = [0.5, 1.0]` and keep both `cpu` and `gpu` in `hardware_list`.
# 3. Results append to `collab_svhn_benchmark_results.csv`.

# %%
# Environment & platform detection
from datetime import datetime, timezone
import os, sys, platform, random, time, subprocess
import numpy as np
import torch

def detect_platform():
    if 'KAGGLE_KERNEL_RUN_TYPE' in os.environ: return 'KAGGLE'
    if 'COLAB_GPU' in os.environ or 'COLAB_RELEASE_TAG' in os.environ: return 'COLAB'
    return 'LOCAL'

def get_cpu_name():
    try:
        # Retrieves the specific CPU model name on Linux (Colab/Kaggle)
        return subprocess.check_output("grep -m 1 'model name' /proc/cpuinfo | cut -d: -f2", shell=True).decode().strip()
    except Exception:
        # Fallback for other environments
        return platform.processor() or "Unknown CPU"

PLATFORM = detect_platform()
CPU_NAME = get_cpu_name()
CUDA_AVAILABLE = torch.cuda.is_available()
AUTO_DEVICE = torch.device('cuda' if CUDA_AVAILABLE else 'cpu')

print('Platform:', PLATFORM)
print('CPU Model:', CPU_NAME)
print('CUDA available:', CUDA_AVAILABLE, '| Auto device:', AUTO_DEVICE)
if CUDA_AVAILABLE:
    print('GPU:', torch.cuda.get_device_name(0))
# Out:
# Platform: COLAB
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# CUDA available: True | Auto device: cuda
# GPU: Tesla T4

# %%
# Ensure SciPy (required by torchvision.datasets.SVHN) is available
try:
    import scipy
except Exception:
    print('Installing SciPy...')
    # %pip -q install scipy
    import scipy

# %%
# ==== Experiment parameters (edit here) ====
fractions = [0.5, 1.0]   # dataset sizes to benchmark (50% vs 100%)
epochs = 5
batch_size = 64
repeats = 3
num_workers = 2
plots = True
save_metrics = 'collab_svhn_benchmark_results.csv'
seed = 42
models_to_run = ['mlp', 'rnn', 'cnn']
hardware_list = ['cpu', 'gpu']
out_dir = 'outputs'
data_dir = './data'

# %%
# Imports & helpers
import os, csv, math
from datetime import datetime
from pathlib import Path
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, random_split, Subset
from torchvision import datasets, transforms
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def set_seeds(s=42):
    random.seed(s); np.random.seed(s); torch.manual_seed(s);
    torch.cuda.manual_seed_all(s);
    torch.backends.cudnn.deterministic = True;
    torch.backends.cudnn.benchmark = False

class MLPClassifier(nn.Module):
    def __init__(self, input_size=3*32*32, hidden_units=256, num_classes=10):
        super().__init__()
        self.model = nn.Sequential(
            nn.Flatten(),
            nn.Linear(input_size, hidden_units), nn.ReLU(),
            nn.Linear(hidden_units, hidden_units), nn.ReLU(),
            nn.Linear(hidden_units, num_classes)
        )
    def forward(self, x): return self.model(x)

class RNNClassifier(nn.Module):
    def __init__(self, input_size=96, hidden_units=128, num_layers=1, num_classes=10):
        super().__init__()
        self.rnn = nn.RNN(input_size=input_size, hidden_size=hidden_units, num_layers=num_layers, batch_first=True, nonlinearity='tanh')
        self.fc = nn.Linear(hidden_units, num_classes)
    def forward(self, x):
        x = x.permute(0,2,3,1)              # (B,C,H,W)->(B,H,W,C)
        x = x.reshape(x.size(0), 32, 32*3)  # seq_len=32, features=96
        out, _ = self.rnn(x)
        last = out[:, -1, :]
        return self.fc(last)

class CNNClassifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3,32,3,padding=1)
        self.conv2 = nn.Conv2d(32,64,3,padding=1)
        self.pool = nn.MaxPool2d(2,2)
        self.drop = nn.Dropout(0.25)
        self.fc1 = nn.Linear(64*8*8, 128)
        self.fc2 = nn.Linear(128, 10)
    def forward(self, x):
        x = F.relu(self.conv1(x)); x = self.pool(x)
        x = F.relu(self.conv2(x)); x = self.pool(x)
        x = torch.flatten(x,1); x = self.drop(x)
        x = F.relu(self.fc1(x)); return self.fc2(x)

def get_transforms():
    return transforms.Compose([
        transforms.ToTensor(),
        transforms.RandomGrayscale(p=0.1),
        transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5)),
    ])

def make_datasets(root, dataset_fraction, seed):
    tfm = get_transforms()
    full_train = datasets.SVHN(root=root, split='train', transform=tfm, download=True)
    test_ds = datasets.SVHN(root=root, split='test', transform=tfm, download=True)
    g = torch.Generator().manual_seed(seed)
    idx = torch.randperm(len(full_train), generator=g).tolist()
    take = int(len(idx) * dataset_fraction)
    sub = Subset(full_train, idx[:take])
    trn_size = int(0.8 * len(sub))
    val_size = len(sub) - trn_size
    train_ds, val_ds = random_split(sub, [trn_size, val_size], generator=g)
    return train_ds, val_ds, test_ds

def get_loaders(train_ds, val_ds, test_ds, batch_size, device_kind, num_workers):
    pin = (device_kind=='gpu')
    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin)
    val_loader   = DataLoader(val_ds,   batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin)
    test_loader  = DataLoader(test_ds,  batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin)
    return train_loader, val_loader, test_loader

def train_one_epoch(model, device, loader, optimizer, criterion):
    model.train(); run_loss=0.0; correct=0; total=0
    for x,y in loader:
        x,y = x.to(device), y.to(device)
        optimizer.zero_grad()
        out = model(x)
        loss = criterion(out, y)
        loss.backward(); optimizer.step()
        run_loss += loss.item()*x.size(0)
        _,pred = torch.max(out,1)
        correct += (pred==y).sum().item(); total += y.size(0)
    return (run_loss/total if total else 0.0), (100.0*correct/total if total else 0.0)

def evaluate(model, device, loader, criterion):
    model.eval(); run_loss=0.0; correct=0; total=0
    with torch.no_grad():
        for x,y in loader:
            x,y = x.to(device), y.to(device)
            out = model(x)
            loss = criterion(out, y)
            run_loss += loss.item()*x.size(0)
            _,pred = torch.max(out,1)
            correct += (pred==y).sum().item(); total += y.size(0)
    return (run_loss/total if total else 0.0), (100.0*correct/total if total else 0.0)

def plot_losses(train_losses, val_losses, out_path):
    plt.figure(figsize=(10,4)); plt.plot(train_losses,label='Train'); plt.plot(val_losses,label='Val');
    plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.tight_layout(); plt.savefig(out_path); plt.close()

def plot_confusion(model, device, loader, classes, out_path):
    model.eval(); P=[]; T=[]
    with torch.no_grad():
        for x,y in loader:
            x=x.to(device); out=model(x); P.extend(out.argmax(1).cpu().numpy().tolist()); T.extend(y.numpy().tolist())
    cm = confusion_matrix(T,P); disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
    fig, ax = plt.subplots(figsize=(6,6)); disp.plot(xticks_rotation='vertical', ax=ax, cmap='Blues', colorbar=False)
    plt.tight_layout(); plt.savefig(out_path); plt.close()

# %%
# Benchmark loop: runs (hardware × fractions × models × repeats) and logs CSV
from pathlib import Path
Path(out_dir).mkdir(parents=True, exist_ok=True)
classes = [str(i) for i in range(10)]

header = ['timestamp','platform_hint','device_kind','device_name','torch_version','cuda_available','cuda_version',
          'model','dataset_fraction','epochs','batch_size','train_samples','val_samples','test_samples',
          'repeat_idx','seed','total_train_time_s','per_epoch_time_s_mean','throughput_samples_per_s',
          'final_train_loss','final_train_acc','final_val_loss','final_val_acc','test_loss','test_acc']
write_header = not os.path.exists(save_metrics)
with open(save_metrics, 'a', newline='') as f:
    wr = csv.writer(f)
    if write_header: wr.writerow(header)

    for hw in hardware_list:
        device_kind = 'gpu' if hw=='gpu' and torch.cuda.is_available() else ('cpu' if hw=='cpu' else 'skip')
        if hw=='gpu' and not torch.cuda.is_available():
            print('[SKIP] GPU selected but CUDA not available.')
            continue
        device = torch.device('cuda') if device_kind=='gpu' else torch.device('cpu')
        name = torch.cuda.get_device_name(0) if device_kind=='gpu' else CPU_NAME
        print('=== Hardware: {} ({}) ==='.format(device_kind.upper(), name))

        for frac in fractions:
            set_seeds(seed)
            train_ds, val_ds, test_ds = make_datasets(data_dir, frac, seed)
            train_loader, val_loader, test_loader = get_loaders(train_ds, val_ds, test_ds, batch_size, device_kind, num_workers)

            for model_name in models_to_run:
                for rep in range(1, repeats+1):
                    set_seeds(seed + rep - 1)
                    if model_name=='mlp': model = MLPClassifier().to(device)
                    elif model_name=='rnn': model = RNNClassifier().to(device)
                    elif model_name=='cnn': model = CNNClassifier().to(device)
                    else: raise ValueError(model_name)

                    criterion = nn.CrossEntropyLoss()
                    optim = torch.optim.Adam(model.parameters(), lr=1e-3)
                    epoch_times = []
                    tr_losses, va_losses = [], []

                    t0 = time.perf_counter()
                    for ep in range(1, epochs+1):
                        e0 = time.perf_counter()
                        tr_loss, tr_acc = train_one_epoch(model, device, train_loader, optim, criterion)
                        if device_kind=='gpu': torch.cuda.synchronize()
                        e1 = time.perf_counter(); epoch_times.append(e1-e0)
                        va_loss, va_acc = evaluate(model, device, val_loader, criterion)
                        tr_losses.append(tr_loss); va_losses.append(va_loss)
                        print('[{}][Rep {}] Epoch {}/{} | Train {:.4f}/{:.2f}% | Val {:.4f}/{:.2f}% | Time {:.2f}s'.format(
                              model_name.upper(), rep, ep, epochs, tr_loss, tr_acc, va_loss, va_acc, epoch_times[-1]))

                    if device_kind=='gpu': torch.cuda.synchronize()
                    total_train_time = time.perf_counter() - t0
                    test_loss, test_acc = evaluate(model, device, test_loader, criterion)
                    per_epoch_mean = float(np.mean(epoch_times)) if epoch_times else 0.0
                    throughput = (len(train_loader.dataset)*epochs)/total_train_time if total_train_time>0 else 0.0

                    # Optional plots
                    if plots:
                        base = os.path.join(out_dir, '{}_{}_rep{}_frac{}'.format(model_name, device_kind, rep, frac))
                        plot_losses(tr_losses, va_losses, base + '_loss.png')
                        plot_confusion(model, device, val_loader, classes, base + '_confusion_val.png')

                    wr.writerow([
                        datetime.now(timezone.utc).isoformat(),
                        os.environ.get('KAGGLE_KERNEL_RUN_TYPE','COLAB' if 'COLAB_GPU' in os.environ else 'LOCAL'),
                        device_kind, name, torch.__version__, torch.cuda.is_available(),
                        (torch.version.cuda if torch.version.cuda is not None else ''),
                        model_name, frac, epochs, batch_size, len(train_loader.dataset), len(val_loader.dataset), len(test_loader.dataset),
                        rep, seed + rep - 1, round(total_train_time,4), round(per_epoch_mean,4), round(throughput,2),
                        round(tr_losses[-1],4), round(tr_acc,2), round(va_losses[-1],4), round(va_acc,2), round(test_loss,4), round(test_acc,2)
                    ])
                    f.flush()
                    print('[DONE] {} | HW {} | Rep {} | Total {:.2f}s | Throughput {:.2f} samples/s | ValAcc {:.2f}% | TestAcc {:.2f}%'.format(
                          model_name.upper(), device_kind, rep, total_train_time, throughput, va_acc, test_acc))

print('Results appended to:', save_metrics)
# Out:
# === Hardware: CPU (Intel(R) Xeon(R) CPU @ 2.00GHz) ===
# 100%|██████████| 182M/182M [01:18<00:00, 2.33MB/s]
# 100%|██████████| 64.3M/64.3M [00:42<00:00, 1.51MB/s]
# [MLP][Rep 1] Epoch 1/5 | Train 1.4478/51.80% | Val 1.0376/67.79% | Time 11.45s
# [MLP][Rep 1] Epoch 2/5 | Train 0.9795/69.33% | Val 0.9146/71.18% | Time 11.71s
# [MLP][Rep 1] Epoch 3/5 | Train 0.8429/73.77% | Val 0.8799/72.37% | Time 12.40s
# [MLP][Rep 1] Epoch 4/5 | Train 0.7571/76.08% | Val 0.7840/75.48% | Time 11.93s
# [MLP][Rep 1] Epoch 5/5 | Train 0.6853/78.63% | Val 0.7723/76.43% | Time 11.80s
# [DONE] MLP | HW cpu | Rep 1 | Total 70.42s | Throughput 2080.58 samples/s | ValAcc 76.43% | TestAcc 73.43%
# [MLP][Rep 2] Epoch 1/5 | Train 1.4321/52.42% | Val 1.0125/68.33% | Time 12.14s
# [MLP][Rep 2] Epoch 2/5 | Train 0.9716/69.88% | Val 0.8946/71.88% | Time 12.12s
# [MLP][Rep 2] Epoch 3/5 | Train 0.8347/74.08% | Val 0.8013/75.18% | Time 12.13s
# [MLP][Rep 2] Epoch 4/5 | Train 0.7571/76.42% | Val 0.7367/77.68% | Time 12.09s
# [MLP][Rep 2] Epoch 5/5 | Train 0.6756/79.13% | Val 0.7371/77.48% | Time 12.20s
# [DONE] MLP | HW cpu | Rep 2 | Total 71.32s | Throughput 2054.27 samples/s | ValAcc 77.48% | TestAcc 74.32%
# [MLP][Rep 3] Epoch 1/5 | Train 1.4163/53.34% | Val 1.0280/67.09% | Time 12.18s
# [MLP][Rep 3] Epoch 2/5 | Train 0.9679/69.75% | Val 0.9115/71.18% | Time 12.10s
# [MLP][Rep 3] Epoch 3/5 | Train 0.8293/74.35% | Val 0.8241/74.16% | Time 12.01s
# [MLP][Rep 3] Epoch 4/5 | Train 0.7489/76.87% | Val 0.7968/75.12% | Time 12.13s
# [MLP][Rep 3] Epoch 5/5 | Train 0.6775/78.98% | Val 0.7471/77.42% | Time 12.01s
# [DONE] MLP | HW cpu | Rep 3 | Total 71.34s | Throughput 2053.61 samples/s | ValAcc 77.42% | TestAcc 73.91%
# [RNN][Rep 1] Epoch 1/5 | Train 2.2113/20.29% | Val 2.2601/18.02% | Time 13.24s
# [RNN][Rep 1] Epoch 2/5 | Train 2.1120/23.79% | Val 1.9513/30.63% | Time 13.38s
# [RNN][Rep 1] Epoch 3/5 | Train 1.8544/34.53% | Val 1.8164/37.50% | Time 13.21s
# [RNN][Rep 1] Epoch 4/5 | Train 1.6903/40.76% | Val 1.6517/41.70% | Time 13.35s
# [RNN][Rep 1] Epoch 5/5 | Train 1.5485/45.85% | Val 1.4802/49.29% | Time 13.44s
# [DONE] RNN | HW cpu | Rep 1 | Total 79.26s | Throughput 1848.55 samples/s | ValAcc 49.29% | TestAcc 47.31%
# [RNN][Rep 2] Epoch 1/5 | Train 2.1829/21.13% | Val 2.0239/28.38% | Time 13.53s
# [RNN][Rep 2] Epoch 2/5 | Train 1.9348/31.15% | Val 1.7831/36.17% | Time 13.39s
# [RNN][Rep 2] Epoch 3/5 | Train 1.7037/40.12% | Val 1.6135/43.80% | Time 13.49s
# [RNN][Rep 2] Epoch 4/5 | Train 1.5541/46.38% | Val 1.4816/49.22% | Time 13.28s
# [RNN][Rep 2] Epoch 5/5 | Train 1.4287/50.95% | Val 1.3562/54.19% | Time 13.18s
# [DONE] RNN | HW cpu | Rep 2 | Total 79.47s | Throughput 1843.59 samples/s | ValAcc 54.19% | TestAcc 52.30%
# [RNN][Rep 3] Epoch 1/5 | Train 2.2212/19.70% | Val 2.1955/18.50% | Time 13.08s
# [RNN][Rep 3] Epoch 2/5 | Train 1.9978/29.18% | Val 1.7757/37.59% | Time 13.39s
# [RNN][Rep 3] Epoch 3/5 | Train 1.7362/39.42% | Val 1.5681/46.18% | Time 13.13s
# [RNN][Rep 3] Epoch 4/5 | Train 1.5431/47.32% | Val 1.5257/49.03% | Time 13.36s
# [RNN][Rep 3] Epoch 5/5 | Train 1.4424/51.24% | Val 1.4006/53.82% | Time 13.34s
# [DONE] RNN | HW cpu | Rep 3 | Total 79.02s | Throughput 1854.03 samples/s | ValAcc 53.82% | TestAcc 51.69%
# [CNN][Rep 1] Epoch 1/5 | Train 1.2137/60.16% | Val 0.6312/82.39% | Time 37.93s
# [CNN][Rep 1] Epoch 2/5 | Train 0.6159/82.05% | Val 0.4973/85.71% | Time 38.91s
# [CNN][Rep 1] Epoch 3/5 | Train 0.5077/85.05% | Val 0.4559/86.66% | Time 39.68s
# [CNN][Rep 1] Epoch 4/5 | Train 0.4413/86.85% | Val 0.4332/87.74% | Time 39.14s
# [CNN][Rep 1] Epoch 5/5 | Train 0.3927/88.24% | Val 0.3984/88.67% | Time 39.47s
# [DONE] CNN | HW cpu | Rep 1 | Total 222.35s | Throughput 658.92 samples/s | ValAcc 88.67% | TestAcc 86.30%
# [CNN][Rep 2] Epoch 1/5 | Train 1.2741/58.08% | Val 0.6319/82.56% | Time 38.81s
# [CNN][Rep 2] Epoch 2/5 | Train 0.6219/82.01% | Val 0.5051/85.68% | Time 40.05s
# [CNN][Rep 2] Epoch 3/5 | Train 0.5218/84.84% | Val 0.4619/86.83% | Time 41.29s
# [CNN][Rep 2] Epoch 4/5 | Train 0.4583/86.61% | Val 0.4244/87.78% | Time 40.63s
# [CNN][Rep 2] Epoch 5/5 | Train 0.4171/87.42% | Val 0.4101/88.11% | Time 39.92s
# [DONE] CNN | HW cpu | Rep 2 | Total 227.51s | Throughput 643.96 samples/s | ValAcc 88.11% | TestAcc 86.62%
# [CNN][Rep 3] Epoch 1/5 | Train 1.2083/60.15% | Val 0.6192/82.36% | Time 38.87s
# [CNN][Rep 3] Epoch 2/5 | Train 0.6094/82.19% | Val 0.5099/85.24% | Time 40.47s
# [CNN][Rep 3] Epoch 3/5 | Train 0.5078/85.05% | Val 0.4448/87.21% | Time 41.33s
# [CNN][Rep 3] Epoch 4/5 | Train 0.4391/86.84% | Val 0.4233/87.70% | Time 41.22s
# [CNN][Rep 3] Epoch 5/5 | Train 0.3905/88.19% | Val 0.4103/88.14% | Time 41.64s
# [DONE] CNN | HW cpu | Rep 3 | Total 232.88s | Throughput 629.12 samples/s | ValAcc 88.14% | TestAcc 86.47%
# [MLP][Rep 1] Epoch 1/5 | Train 1.2015/61.15% | Val 0.9323/71.02% | Time 22.78s
# [MLP][Rep 1] Epoch 2/5 | Train 0.8372/74.43% | Val 0.7673/76.77% | Time 23.02s
# [MLP][Rep 1] Epoch 3/5 | Train 0.7172/78.08% | Val 0.7353/77.75% | Time 22.46s
# [MLP][Rep 1] Epoch 4/5 | Train 0.6428/80.34% | Val 0.6727/80.00% | Time 22.29s
# [MLP][Rep 1] Epoch 5/5 | Train 0.5932/81.89% | Val 0.6660/80.49% | Time 22.90s
# [DONE] MLP | HW cpu | Rep 1 | Total 138.70s | Throughput 2112.72 samples/s | ValAcc 80.49% | TestAcc 77.66%
# [MLP][Rep 2] Epoch 1/5 | Train 1.2142/60.58% | Val 0.9004/71.97% | Time 23.54s
# [MLP][Rep 2] Epoch 2/5 | Train 0.8272/74.47% | Val 0.7932/75.65% | Time 23.39s
# [MLP][Rep 2] Epoch 3/5 | Train 0.7159/78.17% | Val 0.7192/78.75% | Time 23.69s
# [MLP][Rep 2] Epoch 4/5 | Train 0.6443/80.28% | Val 0.7298/78.13% | Time 23.50s
# [MLP][Rep 2] Epoch 5/5 | Train 0.5944/81.76% | Val 0.6709/80.04% | Time 23.46s
# [DONE] MLP | HW cpu | Rep 2 | Total 138.85s | Throughput 2110.41 samples/s | ValAcc 80.04% | TestAcc 77.80%
# [MLP][Rep 3] Epoch 1/5 | Train 1.2114/60.59% | Val 0.9667/69.30% | Time 22.86s
# [MLP][Rep 3] Epoch 2/5 | Train 0.8378/74.21% | Val 0.7866/75.98% | Time 22.64s
# [MLP][Rep 3] Epoch 3/5 | Train 0.7213/77.94% | Val 0.7471/77.24% | Time 22.47s
# [MLP][Rep 3] Epoch 4/5 | Train 0.6413/80.28% | Val 0.7112/78.74% | Time 23.59s
# [MLP][Rep 3] Epoch 5/5 | Train 0.5925/81.86% | Val 0.7013/79.33% | Time 24.07s
# [DONE] MLP | HW cpu | Rep 3 | Total 140.01s | Throughput 2092.94 samples/s | ValAcc 79.33% | TestAcc 75.94%
# [RNN][Rep 1] Epoch 1/5 | Train 2.0849/25.21% | Val 1.8780/33.65% | Time 26.74s
# [RNN][Rep 1] Epoch 2/5 | Train 1.6506/41.88% | Val 1.5252/46.80% | Time 26.32s
# [RNN][Rep 1] Epoch 3/5 | Train 1.3850/52.03% | Val 1.3707/52.48% | Time 26.78s
# [RNN][Rep 1] Epoch 4/5 | Train 1.2768/56.17% | Val 1.2930/55.56% | Time 26.39s
# [RNN][Rep 1] Epoch 5/5 | Train 1.2355/57.87% | Val 1.2186/58.54% | Time 26.60s
# [DONE] RNN | HW cpu | Rep 1 | Total 157.97s | Throughput 1854.98 samples/s | ValAcc 58.54% | TestAcc 57.53%
# [RNN][Rep 2] Epoch 1/5 | Train 2.0346/27.20% | Val 1.8231/36.21% | Time 26.49s
# [RNN][Rep 2] Epoch 2/5 | Train 1.5888/45.02% | Val 1.6006/45.17% | Time 26.62s
# [RNN][Rep 2] Epoch 3/5 | Train 1.3998/52.93% | Val 1.2742/57.84% | Time 26.47s
# [RNN][Rep 2] Epoch 4/5 | Train 1.2709/58.31% | Val 1.2102/60.16% | Time 26.58s
# [RNN][Rep 2] Epoch 5/5 | Train 1.2110/60.60% | Val 1.1598/62.87% | Time 25.86s
# [DONE] RNN | HW cpu | Rep 2 | Total 157.02s | Throughput 1866.11 samples/s | ValAcc 62.87% | TestAcc 60.39%
# [RNN][Rep 3] Epoch 1/5 | Train 2.1171/24.07% | Val 1.8605/33.88% | Time 26.40s
# [RNN][Rep 3] Epoch 2/5 | Train 1.6817/41.45% | Val 1.5173/48.61% | Time 26.54s
# [RNN][Rep 3] Epoch 3/5 | Train 1.4185/52.07% | Val 1.3217/56.18% | Time 26.58s
# [RNN][Rep 3] Epoch 4/5 | Train 1.3282/55.86% | Val 1.2454/59.00% | Time 26.13s
# [RNN][Rep 3] Epoch 5/5 | Train 1.2785/57.85% | Val 1.2706/58.25% | Time 26.53s
# [DONE] RNN | HW cpu | Rep 3 | Total 157.07s | Throughput 1865.59 samples/s | ValAcc 58.25% | TestAcc 56.98%
# [CNN][Rep 1] Epoch 1/5 | Train 0.9266/71.20% | Val 0.5734/83.29% | Time 79.50s
# [CNN][Rep 1] Epoch 2/5 | Train 0.5258/84.79% | Val 0.4405/87.44% | Time 79.56s
# [CNN][Rep 1] Epoch 3/5 | Train 0.4428/86.99% | Val 0.4219/87.65% | Time 80.70s
# [CNN][Rep 1] Epoch 4/5 | Train 0.3895/88.37% | Val 0.3707/89.37% | Time 83.76s
# [CNN][Rep 1] Epoch 5/5 | Train 0.3546/89.34% | Val 0.3550/89.80% | Time 81.65s
# [DONE] CNN | HW cpu | Rep 1 | Total 461.64s | Throughput 634.75 samples/s | ValAcc 89.80% | TestAcc 88.27%
# [CNN][Rep 2] Epoch 1/5 | Train 0.9061/71.61% | Val 0.5322/84.33% | Time 74.94s
# [CNN][Rep 2] Epoch 2/5 | Train 0.4973/85.26% | Val 0.4350/87.35% | Time 78.03s
# [CNN][Rep 2] Epoch 3/5 | Train 0.4158/87.67% | Val 0.3928/88.30% | Time 77.97s
# [CNN][Rep 2] Epoch 4/5 | Train 0.3692/88.90% | Val 0.3634/89.46% | Time 77.90s
# [CNN][Rep 2] Epoch 5/5 | Train 0.3292/90.11% | Val 0.3456/89.89% | Time 76.99s
# [DONE] CNN | HW cpu | Rep 2 | Total 440.14s | Throughput 665.75 samples/s | ValAcc 89.89% | TestAcc 88.71%
# [CNN][Rep 3] Epoch 1/5 | Train 0.9389/70.26% | Val 0.5186/84.98% | Time 78.68s
# [CNN][Rep 3] Epoch 2/5 | Train 0.5005/85.40% | Val 0.4199/87.84% | Time 83.06s
# [CNN][Rep 3] Epoch 3/5 | Train 0.4145/87.73% | Val 0.3702/89.35% | Time 82.15s
# [CNN][Rep 3] Epoch 4/5 | Train 0.3617/89.09% | Val 0.3482/89.61% | Time 81.21s
# [CNN][Rep 3] Epoch 5/5 | Train 0.3253/90.15% | Val 0.3341/90.17% | Time 81.43s
# [DONE] CNN | HW cpu | Rep 3 | Total 461.81s | Throughput 634.51 samples/s | ValAcc 90.17% | TestAcc 88.54%
# === Hardware: GPU (Tesla T4) ===
# [MLP][Rep 1] Epoch 1/5 | Train 1.4478/51.79% | Val 1.0363/67.90% | Time 9.07s
# [MLP][Rep 1] Epoch 2/5 | Train 0.9804/69.08% | Val 0.9053/71.43% | Time 8.22s
# [MLP][Rep 1] Epoch 3/5 | Train 0.8399/74.08% | Val 0.8710/72.74% | Time 9.00s
# [MLP][Rep 1] Epoch 4/5 | Train 0.7553/76.25% | Val 0.7696/76.45% | Time 9.38s
# [MLP][Rep 1] Epoch 5/5 | Train 0.6849/78.61% | Val 0.7561/76.95% | Time 9.32s
# [DONE] MLP | HW gpu | Rep 1 | Total 56.29s | Throughput 2602.58 samples/s | ValAcc 76.95% | TestAcc 72.96%
# [MLP][Rep 2] Epoch 1/5 | Train 1.4311/52.61% | Val 1.0352/67.21% | Time 8.97s
# [MLP][Rep 2] Epoch 2/5 | Train 0.9724/69.81% | Val 0.8923/71.89% | Time 8.14s
# [MLP][Rep 2] Epoch 3/5 | Train 0.8307/74.16% | Val 0.8027/74.95% | Time 8.36s
# [MLP][Rep 2] Epoch 4/5 | Train 0.7453/76.75% | Val 0.7533/76.95% | Time 9.18s
# [MLP][Rep 2] Epoch 5/5 | Train 0.6748/78.70% | Val 0.7152/78.01% | Time 9.29s
# [DONE] MLP | HW gpu | Rep 2 | Total 55.42s | Throughput 2643.77 samples/s | ValAcc 78.01% | TestAcc 74.98%
# [MLP][Rep 3] Epoch 1/5 | Train 1.4151/53.44% | Val 1.0207/67.46% | Time 9.42s
# [MLP][Rep 3] Epoch 2/5 | Train 0.9724/69.74% | Val 0.9109/71.73% | Time 8.44s
# [MLP][Rep 3] Epoch 3/5 | Train 0.8311/74.23% | Val 0.8159/74.49% | Time 8.38s
# [MLP][Rep 3] Epoch 4/5 | Train 0.7474/76.69% | Val 0.7944/75.23% | Time 8.71s
# [MLP][Rep 3] Epoch 5/5 | Train 0.6762/79.14% | Val 0.7204/78.50% | Time 9.41s
# [DONE] MLP | HW gpu | Rep 3 | Total 55.92s | Throughput 2620.04 samples/s | ValAcc 78.50% | TestAcc 74.42%
# [RNN][Rep 1] Epoch 1/5 | Train 2.2119/20.33% | Val 2.1651/22.29% | Time 9.93s
# [RNN][Rep 1] Epoch 2/5 | Train 2.0065/28.02% | Val 1.9122/32.98% | Time 9.73s
# [RNN][Rep 1] Epoch 3/5 | Train 1.7872/36.96% | Val 1.6555/42.48% | Time 9.26s
# [RNN][Rep 1] Epoch 4/5 | Train 1.6147/43.78% | Val 1.5572/45.55% | Time 8.48s
# [RNN][Rep 1] Epoch 5/5 | Train 1.5219/47.27% | Val 1.4849/48.65% | Time 8.53s
# [DONE] RNN | HW gpu | Rep 1 | Total 58.19s | Throughput 2517.81 samples/s | ValAcc 48.65% | TestAcc 47.73%
# [RNN][Rep 2] Epoch 1/5 | Train 2.1832/21.19% | Val 2.0260/27.71% | Time 9.62s
# [RNN][Rep 2] Epoch 2/5 | Train 1.9098/31.73% | Val 1.7770/37.01% | Time 9.68s
# [RNN][Rep 2] Epoch 3/5 | Train 1.6704/42.06% | Val 1.5819/45.99% | Time 9.60s
# [RNN][Rep 2] Epoch 4/5 | Train 1.5488/47.23% | Val 1.4817/50.30% | Time 9.67s
# [RNN][Rep 2] Epoch 5/5 | Train 1.4706/50.55% | Val 1.5282/49.59% | Time 9.20s
# [DONE] RNN | HW gpu | Rep 2 | Total 58.43s | Throughput 2507.38 samples/s | ValAcc 49.59% | TestAcc 47.12%
# [RNN][Rep 3] Epoch 1/5 | Train 2.2155/20.08% | Val 2.1120/24.53% | Time 9.16s
# [RNN][Rep 3] Epoch 2/5 | Train 2.0025/28.55% | Val 1.8776/32.39% | Time 9.56s
# [RNN][Rep 3] Epoch 3/5 | Train 1.7825/37.17% | Val 1.9154/32.62% | Time 9.38s
# [RNN][Rep 3] Epoch 4/5 | Train 1.6526/42.76% | Val 1.5896/46.18% | Time 9.49s
# [RNN][Rep 3] Epoch 5/5 | Train 1.5192/48.39% | Val 1.5506/46.60% | Time 9.50s
# [DONE] RNN | HW gpu | Rep 3 | Total 57.18s | Throughput 2562.11 samples/s | ValAcc 46.60% | TestAcc 44.56%
# [CNN][Rep 1] Epoch 1/5 | Train 1.1929/60.80% | Val 0.5972/83.44% | Time 9.52s
# [CNN][Rep 1] Epoch 2/5 | Train 0.6035/82.40% | Val 0.5092/85.54% | Time 8.99s
# [CNN][Rep 1] Epoch 3/5 | Train 0.5086/85.22% | Val 0.4488/87.03% | Time 9.11s
# [CNN][Rep 1] Epoch 4/5 | Train 0.4416/86.94% | Val 0.4246/88.02% | Time 9.56s
# [CNN][Rep 1] Epoch 5/5 | Train 0.3974/88.05% | Val 0.4274/87.59% | Time 10.10s
# [DONE] CNN | HW gpu | Rep 1 | Total 60.27s | Throughput 2431.06 samples/s | ValAcc 87.59% | TestAcc 85.29%
# [CNN][Rep 2] Epoch 1/5 | Train 1.2495/59.26% | Val 0.6256/82.57% | Time 10.04s
# [CNN][Rep 2] Epoch 2/5 | Train 0.6174/82.22% | Val 0.4883/85.72% | Time 10.12s
# [CNN][Rep 2] Epoch 3/5 | Train 0.5184/84.43% | Val 0.4577/86.50% | Time 10.01s
# [CNN][Rep 2] Epoch 4/5 | Train 0.4491/86.45% | Val 0.4299/87.46% | Time 10.00s
# [CNN][Rep 2] Epoch 5/5 | Train 0.4019/87.88% | Val 0.3997/88.48% | Time 10.08s
# [DONE] CNN | HW gpu | Rep 2 | Total 60.79s | Throughput 2410.16 samples/s | ValAcc 88.48% | TestAcc 86.34%
# [CNN][Rep 3] Epoch 1/5 | Train 1.2328/59.45% | Val 0.5937/83.24% | Time 8.84s
# [CNN][Rep 3] Epoch 2/5 | Train 0.6099/82.22% | Val 0.5094/85.38% | Time 8.93s
# [CNN][Rep 3] Epoch 3/5 | Train 0.5061/85.26% | Val 0.4735/86.39% | Time 9.48s
# [CNN][Rep 3] Epoch 4/5 | Train 0.4460/86.78% | Val 0.4130/88.59% | Time 9.99s
# [CNN][Rep 3] Epoch 5/5 | Train 0.3978/88.07% | Val 0.4124/88.27% | Time 9.96s
# [DONE] CNN | HW gpu | Rep 3 | Total 59.15s | Throughput 2477.11 samples/s | ValAcc 88.27% | TestAcc 86.08%
# [MLP][Rep 1] Epoch 1/5 | Train 1.2052/61.07% | Val 0.9232/71.26% | Time 19.07s
# [MLP][Rep 1] Epoch 2/5 | Train 0.8381/74.38% | Val 0.7716/76.23% | Time 18.63s
# [MLP][Rep 1] Epoch 3/5 | Train 0.7223/77.88% | Val 0.7529/77.36% | Time 18.12s
# [MLP][Rep 1] Epoch 4/5 | Train 0.6434/80.32% | Val 0.6823/79.85% | Time 18.03s
# [MLP][Rep 1] Epoch 5/5 | Train 0.5948/81.72% | Val 0.6729/80.33% | Time 19.16s
# [DONE] MLP | HW gpu | Rep 1 | Total 115.11s | Throughput 2545.61 samples/s | ValAcc 80.33% | TestAcc 77.04%
# [MLP][Rep 2] Epoch 1/5 | Train 1.2147/60.60% | Val 0.9254/71.15% | Time 18.49s
# [MLP][Rep 2] Epoch 2/5 | Train 0.8313/74.42% | Val 0.7950/75.67% | Time 17.94s
# [MLP][Rep 2] Epoch 3/5 | Train 0.7167/78.15% | Val 0.7264/78.21% | Time 18.09s
# [MLP][Rep 2] Epoch 4/5 | Train 0.6443/80.31% | Val 0.7278/78.58% | Time 18.97s
# [MLP][Rep 2] Epoch 5/5 | Train 0.5965/81.76% | Val 0.6708/80.38% | Time 18.29s
# [DONE] MLP | HW gpu | Rep 2 | Total 114.57s | Throughput 2557.59 samples/s | ValAcc 80.38% | TestAcc 76.78%
# [MLP][Rep 3] Epoch 1/5 | Train 1.2108/60.73% | Val 0.9812/68.91% | Time 18.26s
# [MLP][Rep 3] Epoch 2/5 | Train 0.8357/74.35% | Val 0.7774/76.46% | Time 17.94s
# [MLP][Rep 3] Epoch 3/5 | Train 0.7200/78.09% | Val 0.7361/77.66% | Time 19.08s
# [MLP][Rep 3] Epoch 4/5 | Train 0.6430/80.37% | Val 0.7023/78.89% | Time 18.64s
# [MLP][Rep 3] Epoch 5/5 | Train 0.5950/81.82% | Val 0.6919/79.42% | Time 18.28s
# [DONE] MLP | HW gpu | Rep 3 | Total 115.40s | Throughput 2539.13 samples/s | ValAcc 79.42% | TestAcc 77.09%
# [RNN][Rep 1] Epoch 1/5 | Train 2.0611/26.20% | Val 1.7448/38.68% | Time 18.53s
# [RNN][Rep 1] Epoch 2/5 | Train 1.5646/45.69% | Val 1.4355/50.33% | Time 19.15s
# [RNN][Rep 1] Epoch 3/5 | Train 1.3646/53.77% | Val 1.2934/56.46% | Time 19.02s
# [RNN][Rep 1] Epoch 4/5 | Train 1.2537/58.17% | Val 1.3142/55.27% | Time 18.16s
# [RNN][Rep 1] Epoch 5/5 | Train 1.1967/60.29% | Val 1.3479/55.66% | Time 18.31s
# [DONE] RNN | HW gpu | Rep 1 | Total 114.75s | Throughput 2553.64 samples/s | ValAcc 55.66% | TestAcc 52.09%
# [RNN][Rep 2] Epoch 1/5 | Train 2.0365/27.08% | Val 1.7965/36.81% | Time 19.36s
# [RNN][Rep 2] Epoch 2/5 | Train 1.6200/43.84% | Val 1.4899/48.74% | Time 19.39s
# [RNN][Rep 2] Epoch 3/5 | Train 1.3984/52.87% | Val 1.3611/54.33% | Time 18.19s
# [RNN][Rep 2] Epoch 4/5 | Train 1.2851/57.66% | Val 1.2568/58.89% | Time 17.94s
# [RNN][Rep 2] Epoch 5/5 | Train 1.2204/60.35% | Val 1.2545/59.38% | Time 18.62s
# [DONE] RNN | HW gpu | Rep 2 | Total 115.29s | Throughput 2541.69 samples/s | ValAcc 59.38% | TestAcc 58.00%
# [RNN][Rep 3] Epoch 1/5 | Train 2.0514/26.39% | Val 1.7689/38.10% | Time 19.30s
# [RNN][Rep 3] Epoch 2/5 | Train 1.5724/45.98% | Val 1.5448/48.21% | Time 18.10s
# [RNN][Rep 3] Epoch 3/5 | Train 1.3664/54.11% | Val 1.3682/54.14% | Time 18.20s
# [RNN][Rep 3] Epoch 4/5 | Train 1.2444/59.01% | Val 1.2171/59.28% | Time 18.93s
# [RNN][Rep 3] Epoch 5/5 | Train 1.1774/61.72% | Val 1.2010/60.95% | Time 19.51s
# [DONE] RNN | HW gpu | Rep 3 | Total 116.00s | Throughput 2526.15 samples/s | ValAcc 60.95% | TestAcc 58.40%
# [CNN][Rep 1] Epoch 1/5 | Train 0.9217/71.22% | Val 0.5484/84.00% | Time 19.41s
# [CNN][Rep 1] Epoch 2/5 | Train 0.5207/85.02% | Val 0.4537/86.95% | Time 18.78s
# [CNN][Rep 1] Epoch 3/5 | Train 0.4386/87.20% | Val 0.3986/88.50% | Time 18.69s
# [CNN][Rep 1] Epoch 4/5 | Train 0.3873/88.54% | Val 0.3678/89.39% | Time 19.19s
# [CNN][Rep 1] Epoch 5/5 | Train 0.3485/89.51% | Val 0.3510/90.00% | Time 19.73s
# [DONE] CNN | HW gpu | Rep 1 | Total 118.83s | Throughput 2466.00 samples/s | ValAcc 90.00% | TestAcc 88.10%
# [CNN][Rep 2] Epoch 1/5 | Train 0.9221/71.10% | Val 0.5273/84.68% | Time 19.95s
# [CNN][Rep 2] Epoch 2/5 | Train 0.5031/85.19% | Val 0.4269/87.65% | Time 18.89s
# [CNN][Rep 2] Epoch 3/5 | Train 0.4208/87.51% | Val 0.3843/88.56% | Time 18.64s
# [CNN][Rep 2] Epoch 4/5 | Train 0.3683/88.85% | Val 0.3604/89.41% | Time 18.65s
# [CNN][Rep 2] Epoch 5/5 | Train 0.3329/89.91% | Val 0.3377/90.18% | Time 19.77s
# [DONE] CNN | HW gpu | Rep 2 | Total 118.56s | Throughput 2471.53 samples/s | ValAcc 90.18% | TestAcc 88.21%
# [CNN][Rep 3] Epoch 1/5 | Train 0.9208/71.02% | Val 0.5157/85.42% | Time 20.23s
# [CNN][Rep 3] Epoch 2/5 | Train 0.5033/85.36% | Val 0.4283/87.89% | Time 20.00s
# [CNN][Rep 3] Epoch 3/5 | Train 0.4213/87.47% | Val 0.3717/89.13% | Time 18.93s
# [CNN][Rep 3] Epoch 4/5 | Train 0.3669/88.96% | Val 0.3527/89.61% | Time 18.78s
# [CNN][Rep 3] Epoch 5/5 | Train 0.3311/90.05% | Val 0.3423/89.84% | Time 18.34s
# [DONE] CNN | HW gpu | Rep 3 | Total 119.11s | Throughput 2460.12 samples/s | ValAcc 89.84% | TestAcc 88.03%
# Results appended to: collab_svhn_benchmark_results.csv

# %%
# Summarize results: mean±std for time and accuracy, and GPU speedup
import pandas as pd
df = pd.read_csv(save_metrics)
display(df.tail(10))

# Grouped summary
grp = df.groupby(['platform_hint','device_kind','model','dataset_fraction']).agg(
    runs=('repeat_idx','count'),
    total_time_mean=('total_train_time_s','mean'), total_time_std=('total_train_time_s','std'),
    per_epoch_mean=('per_epoch_time_s_mean','mean'),
    throughput_mean=('throughput_samples_per_s','mean'),
    val_acc_mean=('final_val_acc','mean'), val_acc_std=('final_val_acc','std'),
    test_acc_mean=('test_acc','mean'), test_acc_std=('test_acc','std')
).reset_index()
display(grp.sort_values(['model','dataset_fraction','device_kind']))

# Compute GPU speedup vs CPU by matching rows
pivot = grp.pivot_table(index=['platform_hint','model','dataset_fraction'], columns='device_kind', values='total_time_mean')
if 'cpu' in pivot.columns and 'gpu' in pivot.columns:
    pivot['gpu_speedup'] = pivot['cpu'] / pivot['gpu']
    display(pivot)
else:
    print('GPU or CPU results missing; run both hardware configs.')
# Out:
#                            timestamp platform_hint device_kind device_name  \
# 26  2026-04-05T01:37:10.578539+00:00         COLAB         gpu    Tesla T4
# 27  2026-04-05T01:39:21.813357+00:00         COLAB         gpu    Tesla T4
# 28  2026-04-05T01:41:29.005212+00:00         COLAB         gpu    Tesla T4
# 29  2026-04-05T01:43:37.196391+00:00         COLAB         gpu    Tesla T4
# 30  2026-04-05T01:45:44.587021+00:00         COLAB         gpu    Tesla T4
# 31  2026-04-05T01:47:52.404124+00:00         COLAB         gpu    Tesla T4
# 32  2026-04-05T01:50:01.393568+00:00         COLAB         gpu    Tesla T4
# 33  2026-04-05T01:52:13.043206+00:00         COLAB         gpu    Tesla T4
# 34  2026-04-05T01:54:24.631064+00:00         COLAB         gpu    Tesla T4
# 35  2026-04-05T01:56:36.346123+00:00         COLAB         gpu    Tesla T4
#
#    torch_version  cuda_available  cuda_version model  dataset_fraction  \
# 26  2.10.0+cu128            True          12.8   cnn               0.5
# 27  2.10.0+cu128            True          12.8   mlp               1.0
# 28  2.10.0+cu128            True          12.8   mlp               1.0
# 29  2.10.0+cu128            True          12.8   mlp               1.0
# 30  2.10.0+cu128            True          12.8   rnn               1.0
# 31  2.10.0+cu128            True          12.8   rnn               1.0
# 32  2.10.0+cu128            True          12.8   rnn               1.0
# 33  2.10.0+cu128            True          12.8   cnn               1.0
# 34  2.10.0+cu128            True          12.8   cnn               1.0
# 35  2.10.0+cu128            True          12.8   cnn               1.0
#
#     epochs  ...  seed  total_train_time_s  per_epoch_time_s_mean  \
# 26       5  ...    44             59.1455                 9.4408
# 27       5  ...    42            115.1101                18.6052
# 28       5  ...    43            114.5707                18.3558
# 29       5  ...    44            115.4036                18.4399
# 30       5  ...    42            114.7480                18.6324
# 31       5  ...    43            115.2873                18.6995
# 32       5  ...    44            115.9968                18.8082
# 33       5  ...    42            118.8260                19.1590
# 34       5  ...    43            118.5600                19.1797
# 35       5  ...    44            119.1102                19.2546
#
#     throughput_samples_per_s  final_train_loss  final_train_acc  \
# 26                   2477.11            0.3978            88.07
# 27                   2545.61            0.5948            81.72
# 28                   2557.59            0.5965            81.76
# 29                   2539.13            0.5950            81.82
# 30                   2553.64            1.1967            60.29
# 31                   2541.69            1.2204            60.35
# 32                   2526.15            1.1774            61.72
# 33                   2466.00            0.3485            89.51
# 34                   2471.53            0.3329            89.91
# 35                   2460.12            0.3311            90.05
#
#     final_val_loss  final_val_acc  test_loss  test_acc
# 26          0.4124          88.27     0.4930     86.08
# 27          0.6729          80.33     0.8352     77.04
# 28          0.6708          80.38     0.8391     76.78
# 29          0.6919          79.42     0.8385     77.09
# 30          1.3479          55.66     1.4532     52.09
# 31          1.2545          59.38     1.3016     58.00
# 32          1.2010          60.95     1.2729     58.40
# 33          0.3510          90.00     0.4066     88.10
# 34          0.3377          90.18     0.4017     88.21
# 35          0.3423          89.84     0.4048     88.03
#
# [10 rows x 25 columns]
#    platform_hint device_kind model  dataset_fraction  runs  total_time_mean  \
# 0          COLAB         cpu   cnn               0.5     3       227.579867
# 6          COLAB         gpu   cnn               0.5     3        60.066633
# 1          COLAB         cpu   cnn               1.0     3       454.529167
# 7          COLAB         gpu   cnn               1.0     3       118.832067
# 2          COLAB         cpu   mlp               0.5     3        71.026767
# 8          COLAB         gpu   mlp               0.5     3        55.876700
# 3          COLAB         cpu   mlp               1.0     3       139.183100
# 9          COLAB         gpu   mlp               1.0     3       115.028133
# 4          COLAB         cpu   rnn               0.5     3        79.249700
# 10         COLAB         gpu   rnn               0.5     3        57.934700
# 5          COLAB         cpu   rnn               1.0     3       157.353267
# 11         COLAB         gpu   rnn               1.0     3       115.344033
#
#     total_time_std  per_epoch_mean  throughput_mean  val_acc_mean  \
# 0         5.266118       39.955633       644.000000     88.306667
# 6         0.839399        9.648167      2439.443333     88.113333
# 1        12.460999       79.833800       645.003333     89.953333
# 7         0.275150       19.197767      2465.883333     90.006667
# 2         0.527422       12.027133      2062.820000     77.110000
# 8         0.440077        8.885433      2622.130000     77.820000
# 3         0.717194       23.110567      2105.356667     79.953333
# 9         0.422457       18.466967      2547.443333     80.043333
# 4         0.223682       13.318433      1848.723333     52.433333
# 10        0.661886        9.385400      2529.100000     48.280000
# 5         0.531706       26.469700      1862.226667     59.886667
# 11        0.626330       18.713367      2540.493333     58.663333
#
#     val_acc_std  test_acc_mean  test_acc_std
# 0      0.315013      86.463333      0.160104
# 6      0.465224      85.903333      0.546839
# 1      0.192959      88.506667      0.221886
# 7      0.170098      88.113333      0.090738
# 2      0.589661      73.886667      0.445459
# 8      0.792275      74.120000      1.042881
# 3      0.584836      77.133333      1.035825
# 9      0.540401      76.970000      0.166433
# 4      2.728486      50.433333      2.722027
# 10     1.528954      46.470000      1.681993
# 5      2.587708      58.300000      1.830765
# 11     2.716843      56.163333      3.533275
# device_kind                                  cpu         gpu  gpu_speedup
# platform_hint model dataset_fraction
# COLAB         cnn   0.5               227.579867   60.066633     3.788790
#                     1.0               454.529167  118.832067     3.824971
#               mlp   0.5                71.026767   55.876700     1.271134
#                     1.0               139.183100  115.028133     1.209992
#               rnn   0.5                79.249700   57.934700     1.367914
#                     1.0               157.353267  115.344033     1.364208

# %% [markdown]
# ---
# ### Notes
# - TorchVision's SVHN loader remaps the digit '0' to label **0** (the original dataset uses **10** for '0'), keeping class labels in **[0..9]** for `CrossEntropyLoss`.
# - Loading SVHN `.mat` files via TorchVision requires **SciPy**.
# - You can benchmark both **CPU and GPU** in a single GPU-enabled runtime; CPU runs are forced by selecting `device='cpu'`.
